# %%
#download vital python libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#read the data from the csv file
data = pd.read_csv("share-of-students-studying-abroad.csv", delimiter=";")
data
# Out:
#            Country  Year  \
# 0        Australia  2010
# 1        Australia  2011
# 2        Australia  2012
# 3        Australia  2013
# 4           Brazil  2010
# 5           Brazil  2011
# 6           Brazil  2012
# 7           Brazil  2013
# 8            China  2010
# 9            China  2011
# 10           China  2012
# 11           China  2013
# 12           Japan  2010
# 13           Japan  2011
# 14           Japan  2012
# 15          Russia  2010
# 16          Russia  2011
# 17          Russia  2012
# 18          Russia  2013
# 19  United Kingdom  2010
# 20  United Kingdom  2011
# 21  United Kingdom  2012
# 22  United Kingdom  2013
# 23   United States  2010
# 24   United States  2011
# 25   United States  2012
# 26   United States  2013
# 27      Uzbekistan  2010
# 28      Uzbekistan  2011
# 29      Uzbekistan  2012
# 30      Uzbekistan  2013
#
#     Share of students studying abroad all regions and both sexes (%)
# 0                                                 0.8
# ...

# %%
gross = pd.read_csv("gross-enrollment-ratio-in-tertiary-education.csv",delimiter=";")
gross
# Out:
#            Country  Year  Gross enrolment ratio  tertiary both sexes (%)
# 0        Australia  2010                                            80.0
# 1        Australia  2011                                            83.0
# 2        Australia  2012                                            82.0
# 3        Australia  2013                                            86.0
# 4        Australia  2014                                            90.0
# 5           Brazil  2010                                            37.0
# 6           Brazil  2011                                            43.0
# 7           Brazil  2012                                            45.0
# 8           Brazil  2013                                            46.0
# 9           Brazil  2014                                            49.0
# 10           China  2010                                            23.0
# 11           China  2011                                            24.0
# ...

# %%
future = pd.read_csv("Tertiary-education-in-future.csv",delimiter=";")
future
# Out:
#            Country  Year  \
# 0        Australia  2030
# 1        Australia  2035
# 2        Australia  2040
# 3        Australia  2045
# 4        Australia  2050
# 5           Brazil  2030
# 6           Brazil  2035
# 7           Brazil  2040
# 8           Brazil  2045
# 9           Brazil  2050
# 10           China  2030
# 11           China  2035
# 12           China  2040
# 13           China  2045
# 14           China  2050
# 15           Japan  2030
# 16           Japan  2035
# 17           Japan  2040
# 18           Japan  2045
# 19           Japan  2050
# 20          Russia  2030
# 21          Russia  2035
# 22          Russia  2040
# 23          Russia  2045
# 24          Russia  2050
# 25  United Kingdom  2030
# 26  United Kingdom  2035
# 27  United Kingdom  2040
# 28  United Kingdom  2045
# 29  United Kingdom  2050
# 30   United States  2030
# 31   United States  2035
# 32   United States  2040
# 33   United States  2045
# 34   United States  2050
# ...

# %%
#Our csv file is imported successfully

# %% [markdown]
# ## Now let  do the graph about share of students abroad between <strong>2010</strong> and <strong>2013</strong>

# %%
#Now let`s create a bar-chart of share of students studying abroad in 2010
import matplotlib.pyplot as plt

x=["Australia","Brazil","China","Japan","Russia","UK","USA","Uzbekistan"]
y=["0.8%","0.4%","0.2%","0.1%","0.5%","0.9%","0.2%","0.8%"]
y.sort()
c=["black","green","purple","yellow","red","blue","gray","orange"]
plt.bar(x,y, label="2010 year", width=0.6, color=c)
plt.xlabel("Country")
plt.ylabel("Percentage")
plt.title("Share of students studying abroad")
plt.legend()
plt.show()

# %%
#Now let`s create a bar-chart of share of students studying abroad in 2011
import matplotlib.pyplot as plt

x=["Australia","Brazil","China","Japan","Russia","UK","USA","Uzbekistan"]
y=["0.8%","0.4%","0.2%","0.9%","0.5%","0.1%","0.2%","0.8%"]
c=["black","green","purple","yellow","red","blue","gray","orange"]
y.sort()
plt.bar(x,y, label="2011 year", width=0.6, color=c)
plt.xlabel("Country")
plt.ylabel("Percentage")
plt.title("Share of students studying abroad")
plt.legend()
plt.show()

# %%
#Now let`s create a bar-chart of share of students studying abroad in 2012
import matplotlib.pyplot as plt

x=["Australia","Brazil","China","Japan","Russia","UK","USA","Uzbekistan"]
y=["0.8%","0.4%","0.2%","0.8%","0.6%","0.1%","0.2%","0.9%"]
c=["black","green","purple","yellow","red","blue","gray","orange"]
y.sort()
plt.bar(x,y, label="2012 year", width=0.6, color=c)
plt.xlabel("Country")
plt.ylabel("Percentage")
plt.title("Share of students studying abroad")
plt.legend()
plt.show()

# %%
#Now let`s create a bar-chart of share of students studying abroad in 2013
import matplotlib.pyplot as plt

x=["Australia","Brazil","China","Japan","Russia","UK","USA","Uzbekistan"]
y=["0.8%","0.4%","0.2%","0.8%","0.6%","0.1%","0.3%","0.9%"]
c=["black","green","purple","yellow","red","blue","gray","orange"]
y.sort()
plt.bar(x,y, label="2013 year", width=0.6, color=c)
plt.xlabel("Country")
plt.ylabel("Percentage")
plt.title("Share of students studying abroad")
plt.legend()
plt.show()

# %% [markdown]
# ## Let`s turn to the second svg file

# %% [markdown]
# Gross enrolment ratio tertiary education both sexes around the world from 2010 to 2014

# %%
#Now let`s create a line-graph about the level of tertiary education gross enrolment from 2010
import matplotlib.pyplot as plt
   
Country = ["Australia","Brazil","China","Japan","Russia","UK","USA"]
gross_enrolment = [80,37,23,58,75,59,94,]
  
plt.plot(Country, gross_enrolment, color="green", marker="s",  ms = 10)
plt.title("The persentage of gross enrolment in 2010", fontsize=10)
plt.xlabel("Country", fontsize=15)
plt.ylabel("Gross enrolment", fontsize=15)
plt.grid(True)
plt.show()

# %%
#Now let`s create a line-graph about the level of tertiary education gross enrolment from 2011
import matplotlib.pyplot as plt
   
Country = ["Australia","Brazil","China","Japan","Russia","UK","USA"]
gross_enrolment = [83,43,24,59,76,58,96,]
  
plt.plot(Country, gross_enrolment, color="blue", marker="o",  ms = 10)
plt.title("The persentage of gross enrolment in 2011", fontsize=10)
plt.xlabel("Country", fontsize=15)
plt.ylabel("Gross enrolment", fontsize=15)
plt.grid(True)
plt.show()

# %%
#Now let`s create a line-graph about the level of tertiary education gross enrolment from 2012
import matplotlib.pyplot as plt
   
Country = ["Australia","Brazil","China","Japan","Russia","UK","USA"]
gross_enrolment = [82,45,27,61,76.3,59,94]
  
plt.plot(Country, gross_enrolment, color="yellow", marker = '8', ms = 10)
plt.title("The persentage of gross enrolment in 2012", fontsize=10)
plt.xlabel("Country", fontsize=15)
plt.ylabel("Gross enrolment", fontsize=15)
plt.grid(True)
plt.show()

# %%
#Now let`s create a line-graph about the level of tertiary education gross enrolment from 2013
import matplotlib.pyplot as plt
   
Country = ["Australia","Brazil","China","Japan","Russia","UK","USA"]
gross_enrolment = [86,46,30,62,77,56.4,88]
  
plt.plot(Country, gross_enrolment, color="orange", marker = 'p', ms = 10)
plt.title("The persentage of gross enrolment in 2013", fontsize=10)
plt.xlabel("Country", fontsize=15)
plt.ylabel("Gross enrolment", fontsize=15)
plt.grid(True)
plt.show()

# %%
#Now let`s create a line-graph about the level of tertiary education gross enrolment from 2014
import matplotlib.pyplot as plt
   
Country = ["Australia","Brazil","China","Japan","Russia","UK","USA"]
gross_enrolment = [86,46,30,62,77,56.4,88]
  
plt.plot(Country, gross_enrolment, color="red", marker = 'o', ms = 10)
plt.title("The persentage of gross enrolment in 2013", fontsize=10)
plt.xlabel("Country", fontsize=15)
plt.ylabel("Gross enrolment", fontsize=15)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Let`s turn to the last  svg file

# %% [markdown]
# The proportion of Tertiary education for aged 15+ during two decades(2030-2050)

# %%
#Now let`s create a pie-chart in first three countries during two decades.

# %%
# Start a chart with initial country from the svg file.

# First proportion 
fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

recipe = ["2030 year - 31%","2035 year - 32%","2040 year - 34%","2045 year - 35%","2050 year - 37%"]

data = [31,32,34,35,37]

wedges, texts = ax.pie(data, wedgeprops=dict(width=0.5), startangle=-40)

bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
kw = dict(arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(recipe[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                horizontalalignment=horizontalalignment, **kw)

ax.set_title("The proportion of tertiary education in Australia")

plt.show()

# %%
# Second proportion 

fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

recipe = ["2030 year - 10%","2035 year - 11%","2040 year - 12%","2045 year - 13%","2050 year - 15%"]

data = [10,11,12,13,15]

wedges, texts = ax.pie(data, wedgeprops=dict(width=0.5), startangle=-40)

bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
kw = dict(arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(recipe[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                horizontalalignment=horizontalalignment, **kw)

ax.set_title("The proportion of tertiary education in Brazil")

plt.show()

# %%
# Third proportion 

fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

recipe = ["2030 year - 9%","2035 year - 10%","2040 year - 11%","2045 year - 12%","2050 year - 14%"]

data = [9,10,11,12,14]

wedges, texts = ax.pie(data, wedgeprops=dict(width=0.5), startangle=-40)

bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
kw = dict(arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(recipe[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                horizontalalignment=horizontalalignment, **kw)

ax.set_title("The proportion of tertiary education in China")

plt.show()
